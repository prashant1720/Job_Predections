# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv(r"C:\Users\griet\Desktop\test2.csv")

# %%
data=data.drop('Date',axis=1)

# %%
data.head()
# Out:
#           User full name              Email address  I like to work on cars  \
# 0  19241A0101 19241A0101    ruhaillone007@gmail.com                     Yes
# 1  19241A0102 19241A0102      asaiteja883@gmail.com                     Yes
# 2  19241A0103 19241A0103  barishettyshiva@gmail.com                     Yes
# 3  19241A0104 19241A0104    varuntej.1704@gmail.com                      No
# 4  19241A0105 19241A0105   vamshinayak460@gmail.com                      No
#
#   I like to do puzzles  I am good at working independently  \
# 0                  YES                                 YES
# 1                   NO                                 YES
# 2                  YES                                 YES
# 3                   NO                                 YES
# 4                  YES                                 YES
#
#   I like to work in teams I am an ambitious person, I set goals for myself  \
# ...

# %%
data['User full name'] = [x.split(" ")[0] for x in data['User full name']]

# %%
data.head()
# Out:
#   User full name              Email address  I like to work on cars  \
# 0     19241A0101    ruhaillone007@gmail.com                     Yes
# 1     19241A0102      asaiteja883@gmail.com                     Yes
# 2     19241A0103  barishettyshiva@gmail.com                     Yes
# 3     19241A0104    varuntej.1704@gmail.com                      No
# 4     19241A0105   vamshinayak460@gmail.com                      No
#
#   I like to do puzzles  I am good at working independently  \
# 0                  YES                                 YES
# 1                   NO                                 YES
# 2                  YES                                 YES
# 3                   NO                                 YES
# 4                  YES                                 YES
#
#   I like to work in teams I am an ambitious person, I set goals for myself  \
# 0                      NO                                              YES
# ...

# %%
 data.to_excel('final.xlsx', sheet_name='sheet1', index=False)
